# %% [markdown]
# # Mark down
# 1. Foods
#     - jkjldk
#     - jkjlkk
#         * jkljklj
#         * jkljkljkl
# 2. likes
#     - kjknklj
#     - kljkljlj

# %%
print (x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-78996ecd3f1c> in <module>()
# ----> 1 print (x)
#
# NameError: name 'x' is not defined

# %%
x = 33

# %%
print (x)
# Out:
# 33

# %%
print ('weight in kg:', x)
# Out:
# ('weight in kg:', 33)

# %%
print ("weight in kg:" 'x')
# Out:
# weight in kg:x

# %%
x= 58
y = x 
x = 2

# %%
print y
# Out:
# 58

# %%
print x
# Out:
# 2

# %%
type x
# Out:
#   File "<ipython-input-14-87c26250c30f>", line 1
#     type x
#          ^
# SyntaxError: invalid syntax

# %%
type (x)
# Out:
# int

# %%
print ("fitness " + 'x')
# Out:
# fitness x

# %%
print (int('2')+ 4)
#different way of adding integers and usning the string function
#the int allows it to become an integer
# Out:
# 6

# %%
weight_unit = 34

# %%
weight_kg = 22

# %%
print ('our weight is equal to', weight_unit, 'is', weight_kg)
# Out:
# ('our weight is equal to', 34, 'is', 22)

# %%
x= '242'

# %%
b = 'd1c12'

# %%
x + b
# Out:
# '242d1c12'

# %%
# %whos
# Out:
# Variable      Type    Data/Info
# -------------------------------
# b             str     d1c12
# weight_kg     int     22
# weight_unit   int     34
# x             str     242
# y             int     58

# %%
atom_name = 'carbon'

# %%
print (atom_name)
# Out:
# carbon

# %%
print (atom_name[4:4])

# %%
print (atom_name[2:5])
print (atom_name[1:3])
print (atom_name[:3])
print (atom_name[1:])
print (atom_name[1:-5])

#this is used to include certain parts of a value for the cariable
#this example is using carbon
#the 2:5 means itll start on r which is 2 because evertying starts on 0 
# then itll be rbo because 2-5 means everyting from 2-5 excluding 5
# Out:
# rbo
# ar
# car
# arbon

# %%
p
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-af74eb001c35> in <module>()
# ----> 1 value (atom_name)
#
# NameError: name 'value' is not defined

# %%
print (round(3.16678431686481723687, 4)) 
#this is the round function
# Out:
# 3.1668

# %%
round?
help(round)
# Out:
# Help on built-in function round in module __builtin__:
#
# round(...)
#     round(number[, ndigits]) -> floating point number
#
#     Round a number to a given precision in decimal digits (default 0 digits).
#     This always returns a floating point number.  Precision may be negative.

# %%
age = 53

# %%
remaining = 100 - age

# %% [markdown]
# import math

# %%
import math

# %%
print ('pi is ', math.pi)
# Out:
# ('pi is ', 3.141592653589793)

# %%
help (math)
# Out:
# Help on module math:
#
# NAME
#     math
#
# FILE
#     /Users/raulrodriguez/anaconda2/lib/python2.7/lib-dynload/math.so
#
# MODULE DOCS
#     https://docs.python.org/library/math
#
# DESCRIPTION
#     This module is always available.  It provides access to the
#     mathematical functions defined by the C standard.
#
# FUNCTIONS
#     acos(...)
#         acos(x)
#
#         Return the arc cosine (measured in radians) of x.
#
#     acosh(...)
#         acosh(x)
#
#         Return the inverse hyperbolic cosine of x.
#
#     asin(...)
#         asin(x)
#
#         Return the arc sine (measured in radians) of x.
#
#     asinh(...)
#         asinh(x)
#
#         Return the inverse hyperbolic sine of x.
#
#     atan(...)
#         atan(x)
#
#         Return the arc tangent (measured in radians) of x.
#
#     atan2(...)
#         atan2(y, x)
#
#         Return the arc tangent (measured in radians) of y/x.
#         Unlike atan(y/x), the signs of both x and y are considered.
#
# ...

# %%
import math as m

# %%
cd
# Out:
# /Users/raulrodriguez

# %%
cd desktop
# Out:
# /Users/raulrodriguez/Desktop

# %%
cd ..
# Out:
# /Users/raulrodriguez

# %%
ls
# Out:
# Applications/     Library/          Public/           irisdata.csv
# Desktop/          Movies/           anaconda2/        irisdata2.csv
# Documents/        Music/            apmplanner2/      mapscache/
# Downloads/        Pictures/         dronesim          spyder_crash.log

# %%
import pandas as pd

# %%
data = pd.read_csv('/users/raulrodriguez/downloads/data/gapminder_gdp_oceania.csv')

# %%
print data
# Out:
#        country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Australia     10039.59564     10949.64959     12217.22686
# 1  New Zealand     10556.57566     12247.39532     13175.67800
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     14526.12465     16788.62948     18334.19751     19477.00928
# 1     14463.91893     16046.03728     16233.71770     17632.41040
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     21888.88903     23424.76683     26997.93657     30687.75473
# 1     19007.19129     18363.32494     21050.41377     23189.80135
#
#    gdpPercap_2007
# 0     34435.36744
# 1     25185.00911

# %%
print data.describe
# Out:
# <bound method DataFrame.describe of        country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Australia     10039.59564     10949.64959     12217.22686
# 1  New Zealand     10556.57566     12247.39532     13175.67800
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     14526.12465     16788.62948     18334.19751     19477.00928
# 1     14463.91893     16046.03728     16233.71770     17632.41040
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     21888.88903     23424.76683     26997.93657     30687.75473
# 1     19007.19129     18363.32494     21050.41377     23189.80135
#
#    gdpPercap_2007
# 0     34435.36744
# 1     25185.00911  >

# %%
pwd
# Out:
# u'/Users/raulrodriguez'

# %%
cd downloads
# Out:
# /Users/raulrodriguez/Downloads

# %%
ls
# Out:
# 2016TurboTaxReturn.pdf
# 478584_335892459781231_851866561_o.jpg
# ASTROCommandCenter-2.dmg
# ASTROCommandCenter.dmg
# Alpha Resume17.docx
# DEV236x_Introduction_to_Python_Unit_1/
# DEV236x_Introduction_to_Python_Unit_1.zip
# Descripcion_de_lo_que_se_espera_a_cada_nivel.doc
# IMGP0075.JPG
# Imperfecto.doc
# Install Spotify.app/
# League of Legends NA.dmg
# MOD01_1-1.1_Intro_Python.ipynb
# Memorandum_about_grades_Final.doc
# Memorandum_about_grades_Midterm.doc
# Midterm 105 - 1 and 2.doc
# OPI 105 Section 1 and 2.doc
# OPI_Summary_for_Grading_Rubric.doc
# Por_y_para.doc
# RStudio-1.0.153.dmg
# Raul Final Memorandun.doc
# Raul RESUME 2017-2.docx
# Raul RESUME 2017-3.docx
# Raul Resume 2017.docx
# Raul Rodriguez CV2017.pdf
# SPAN306-02SyllabusSpring2017(2).doc
# SPAN306-02SyllabusSpring2017.doc
# SSR_TSRPT.pdf
# Senior Picture.jpeg
# WORK AVAILABILITY FORM.docx
# apm_planner_2.0.25_osx.dmg
# data/
# europa_161019140229_tm-1,1,18814_tr-0,0,41_rm-1,0,18331_rr-0,0,41.afw
# ...

# %%
cd
# Out:
# /Users/raulrodriguez

# %%
ls
# Out:
# Applications/     Library/          Public/           irisdata.csv
# Desktop/          Movies/           anaconda2/        irisdata2.csv
# Documents/        Music/            apmplanner2/      mapscache/
# Downloads/        Pictures/         dronesim          spyder_crash.log

# %%
data = pd.read_csv('/users/raulrodriguez/downloads/data/gapminder_gdp_europe.csv')

# %%
data.T
# Out:
#                      0        1        2                       3         4   \
# country         Albania  Austria  Belgium  Bosnia and Herzegovina  Bulgaria
# gdpPercap_1952  1601.06  6137.08  8343.11                 973.533   2444.29
# gdpPercap_1957  1942.28   8842.6  9714.96                 1353.99   3008.67
# gdpPercap_1962  2312.89  10750.7  10991.2                 1709.68   4254.34
# gdpPercap_1967   2760.2  12834.6    13149                 2172.35      5577
# gdpPercap_1972  3313.42  16661.6  16672.1                 2860.17   6597.49
# gdpPercap_1977     3533  19749.4    19118                 3528.48   7612.24
# gdpPercap_1982  3630.88  21597.1  20979.8                 4126.61   8224.19
# gdpPercap_1987  3738.93  23687.8  22525.6                 4314.11   8239.85
# gdpPercap_1992  2497.44    27042  25575.6                 2546.78   6302.62
# gdpPercap_1997  3193.05  29095.9  27561.2                 4766.36   5970.39
# ...

# %%
data.describe
# Out:
# <bound method DataFrame.describe of                    country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0                  Albania     1601.056136     1942.284244     2312.888958
# 1                  Austria     6137.076492     8842.598030    10750.721110
# 2                  Belgium     8343.105127     9714.960623    10991.206760
# 3   Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# 4                 Bulgaria     2444.286648     3008.670727     4254.337839
# 5                  Croatia     3119.236520     4338.231617     5477.890018
# 6           Czech Republic     6876.140250     8256.343918    10136.867130
# 7                  Denmark     9692.385245    11099.659350    13583.313510
# 8                  Finland     6424.519071     7545.415386     9371.842561
# 9                   France     7029.809327     8662.834898    10560.485530
# 10                 Germany     7144.114393    10187.826650    12902.462910
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of                    country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0                  Albania     1601.056136     1942.284244     2312.888958
# 1                  Austria     6137.076492     8842.598030    10750.721110
# 2                  Belgium     8343.105127     9714.960623    10991.206760
# 3   Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# 4                 Bulgaria     2444.286648     3008.670727     4254.337839
# 5                  Croatia     3119.236520     4338.231617     5477.890018
# 6           Czech Republic     6876.140250     8256.343918    10136.867130
# 7                  Denmark     9692.385245    11099.659350    13583.313510
# 8                  Finland     6424.519071     7545.415386     9371.842561
# 9                   France     7029.809327     8662.834898    10560.485530
# 10                 Germany     7144.114393    10187.826650    12902.462910
# ...

# %%
data?

# %%
data2 = pd.read_csv('/users/raulrodriguez/downloads/data/gapminder_gdp_asia.csv', index_col='country')
stats = data2.describe
print(stats)
data2_t = data.T
print (head)
# Out:
# <bound method DataFrame.describe of                     gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Afghanistan             779.445314      820.853030      853.100710
# Bahrain                9867.084765    11635.799450    12753.275140
# Bangladesh              684.244172      661.637458      686.341554
# Cambodia                368.469286      434.038336      496.913648
# China                   400.448611      575.987001      487.674018
# Hong Kong China        3054.421209     3629.076457     4692.648272
# India                   546.565749      590.061996      658.347151
# Indonesia               749.681655      858.900271      849.289770
# Iran                   3035.326002     3290.257643     4187.329802
# Iraq                   4129.766056     6229.333562     8341.737815
# Israel                 4086.522128     5385.278451     7105.630706
# Japan                  3216.956347     4317.694365     6576.649461
# ...

# %%
data
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
data.index
# Out:
#   File "<ipython-input-140-e406cd1d5ea2>", line 1
#     data.indexfuck you
#                      ^
# SyntaxError: invalid syntax

# %%
data
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
data.loc(['Italy':'Poland','gdpPercap_1962':'gdpPercap_1972'])
# Out:
#   File "<ipython-input-134-8f7f1fd0c25b>", line 1
#     data.loc(['Italy':'Poland','gdpPercap_1962':'gdpPercap_1972'])
#                      ^
# SyntaxError: invalid syntax

# %%
cd
# Out:
# /Users/raulrodriguez

# %%
# %matpolotlib inline
import matplot.lib as plt
# Out:
# ERROR:root:Line magic function `%matpolotlib` not found.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-148-ea115137a558> in <module>()
#       1 get_ipython().magic(u'matpolotlib inline')
# ----> 2 import matplot.lib as plt
#
# ImportError: No module named matplot.lib
